# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.arange(10)
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.randn(50).cumsum(), 'k--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig, axes = plt.subplots(2, 3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8E3E42708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8E3E75108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8E3EA6C48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8E3EDE748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8E3F18208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8E3F50148>]],
#       dtype=object)

# %%
axes[0,1].hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
# Out:
# (array([ 2.,  1.,  1.,  2.,  2.,  2.,  3.,  6., 12., 11., 13.,  7., 11.,
#         12.,  2.,  3.,  6.,  0.,  3.,  1.]),
#  array([-2.81302733, -2.52175892, -2.23049052, -1.93922211, -1.64795371,
#         -1.35668531, -1.0654169 , -0.7741485 , -0.48288009, -0.19161169,
#          0.09965671,  0.39092512,  0.68219352,  0.97346193,  1.26473033,
#          1.55599873,  1.84726714,  2.13853554,  2.42980395,  2.72107235,
#          3.01234075]),
#  <a list of 20 Patch objects>)

# %%
plt.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None,
wspace=None, hspace=None)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot?
